# %%
# %run ../script/GatherData

# %%
# %run ../script/Preprocess

# %%
# run with raw data
# %run ../script/Preprocess
# %run ../script/Evaluation
# Out:
# ************************************************************
#                          MaxEnt: 2
# ************************************************************
#
#
# [[263  44   1   1]
#  [ 16 314  13   1]
#  [  4  60  24   0]
#  [  2   4   4   0]]
#               precision    recall  f1-score   support
#
#          GUI       0.92      0.85      0.89       309
#        LOGIC       0.74      0.91      0.82       344
#        MODEL       0.57      0.27      0.37        88
#         PREF       0.00      0.00      0.00        10
#
#     accuracy                           0.80       751
#    macro avg       0.56      0.51      0.52       751
# weighted avg       0.79      0.80      0.78       751
#
# Accuracy score:0.800266311584554
# MCC:0.6657837142227145
# ************************************************************
# +-------------------------------+---------+---------+---------+-------------+
# |                               |     GUI |   LOGIC |   MODEL |        PREF |
# ...

# %%
# Use the libraries, and parse the data
# %run ../script/Preprocess
# %run ../script/Evaluation
# Out:
# ************************************************************
#                          MaxEnt: 9
# ************************************************************
#
#
# [[295  11   4   0]
#  [  3 341   1   0]
#  [  0   5  82   0]
#  [  2   7   1   0]]
#               precision    recall  f1-score   support
#
#          GUI       0.98      0.95      0.97       310
#        LOGIC       0.94      0.99      0.96       345
#        MODEL       0.93      0.94      0.94        87
#         PREF       0.00      0.00      0.00        10
#
#     accuracy                           0.95       752
#    macro avg       0.71      0.72      0.72       752
# weighted avg       0.94      0.95      0.95       752
#
# Accuracy score:0.9547872340425532
# MCC:0.9254600353037531
# ************************************************************
# +-------------------------------+---------+----------+----------+----------+
# |                               |     GUI |    LOGIC |    MODEL |     PREF |
# ...

# %%
# Use libraries, public variables, and comments, then parse the data
# %run ../script/Preprocess
# %run ../script/Evaluation
# Out:
# ************************************************************
#                          MaxEnt: 9
# ************************************************************
#
#
# [[273  28   8   1]
#  [  8 329   8   0]
#  [  0  44  41   2]
#  [  2   5   2   1]]
#               precision    recall  f1-score   support
#
#          GUI       0.96      0.88      0.92       310
#        LOGIC       0.81      0.95      0.88       345
#        MODEL       0.69      0.47      0.56        87
#         PREF       0.25      0.10      0.14        10
#
#     accuracy                           0.86       752
#    macro avg       0.68      0.60      0.63       752
# weighted avg       0.85      0.86      0.85       752
#
# Accuracy score:0.8563829787234043
# MCC:0.7623760206280153
# ************************************************************
# +-------------------------------+---------+---------+----------+-----------+
# |                               |     GUI |   LOGIC |    MODEL |      PREF |
# ...
