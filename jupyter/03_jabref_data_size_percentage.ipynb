# %%
# Imports and scripts
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import pathmagic
# %matplotlib inline
with pathmagic.context():
    import Preprocess as Prep
    import RelativePaths as RP
    import Evaluation as Eva
    import GatherData as Gather
    import Graphs
    import Utils

system = 'jabref'
# Out:
# [nltk_data] Downloading package stopwords to /home/alex/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# File containing settings
path_to_yaml = '../config.yaml'
config = Utils.read_yaml_file(path_to_yaml)

files = config['file locations'][system]
preprocess_settings = config['preprocess settings list']

# %%
# set file_locations which will be relative to computer in use
from pathlib import Path

system_folder = str(Path.cwd().parent / files['system folder'])

raw_data_csv = str(Path.cwd().parent / files['raw data'])
tmp_csv = str(Path.cwd().parent / files['tmp data'])

processed_data_csv = str(Path.cwd().parent / files['data size percentage'])

# %%
Gather.gather_architectural_concerns_data(system_folder, raw_data_csv)

# %%
dataset_df = pd.read_csv(raw_data_csv)
y_labels = dataset_df.Label.unique()
x_quantity = [len(dataset_df.loc[dataset_df['Label']==label]) for label in y_labels]
tmp_df = pd.DataFrame({
    'Labels' : y_labels,
    'Quantity' : x_quantity
})
tmp_df = tmp_df.sort_values(by=['Quantity'])
plt.style.use("seaborn-whitegrid")
plt.barh(y=tmp_df.Labels, width=tmp_df.Quantity)
for i, v in enumerate(tmp_df.Quantity):
    plt.text(v, i, str(v), color='black', fontweight='bold', ha='left', va='center')

plt.xlabel('Quantities')
plt.ylabel('Labels')
plt.title('Shows the number of files for every label, from JabRef')
# Out:
# Text(0.5, 1.0, 'Shows the number of files for every label, from JabRef')

# %% [markdown]
# ## Preprocessing

# %%
setting = preprocess_settings['s0']


Prep.preprocess_settings(setting, raw_data_csv, processed_data_csv)

processed_data_df = pd.read_csv(processed_data_csv)
df_sliced = Utils.remove_concerns_under_quantity_threshold(processed_data_df)

# %% [markdown]
# ----

# %% [markdown]
# ## Testing:
#     - Test different sample sizes: 5,10,15,20%

# %%
maxEnt_accuracy_test1 = []
svm_accuracy_test1 = []
naive_accuracy_test1 = []

maxEnt_precision_test1 = []
svm_precision_test1 = []
naive_precision_test1 = []

maxEnt_recall_test1 = []
svm_recall_test1 = []
naive_recall_test1 = []

maxEnt_f1_test1 = []
svm_f1_test1 = []
naive_f1_test1 = []

# %% [markdown]
# # Test 1
# - Train-size: 10%
# - Test-size: 90 %
# - feature representation = Bag-of-words
# - Settings = s0

# %%
test_size=0.9
fold_quantity = 100
feature_representation = CountVectorizer()
# Train and gather evaluation metrics
evaluate = Eva.Evaluation(df_sliced, feature_representation, test_size, fold_quantity)
h = df_sliced.Label
classifier_max_ent , metrics_max_ent = evaluate.evaluate_MaxEnt()
classifier_svm , metrics_svm = evaluate.evaluate_SVM()
classifier_naive, metrics_naive = evaluate.evaluate_Naive_Bayes()

metrics = {
    'maxEnt': metrics_max_ent,
    'SVM': metrics_svm,
    'Naive': metrics_naive
}

# %% [markdown]
# # Evaluate

# %%
Graphs.plot_horizontal_graphs(metrics, 'norm')

# %% [markdown]
# # Classification report

# %%
Graphs.plot_horizontal_graphs(metrics, 'report')

# %% [markdown]
# # Prediction averages

# %%
Graphs.plot_predictionScoreAverage(metrics_max_ent, classifier_max_ent)
Graphs.plot_predictionScoreAverage(metrics_naive, classifier_naive)
Graphs.plot_predictionScoreAverage(metrics_svm, classifier_svm)

# %%
maxEnt_accuracy_test1.append(metrics_max_ent.get_accuracy_score())
svm_accuracy_test1.append(metrics_svm.get_accuracy_score())
naive_accuracy_test1.append(metrics_naive.get_accuracy_score())

maxEnt_precision_test1.append(metrics_max_ent.get_precision_score())
svm_precision_test1.append(metrics_svm.get_precision_score())
naive_precision_test1.append(metrics_naive.get_precision_score())

maxEnt_recall_test1.append(metrics_max_ent.get_recall_score())
svm_recall_test1.append(metrics_svm.get_recall_score())
naive_recall_test1.append(metrics_naive.get_recall_score())

maxEnt_f1_test1.append(metrics_max_ent.get_f1_score())
svm_f1_test1.append(metrics_svm.get_f1_score())
naive_f1_test1.append(metrics_naive.get_f1_score())

# %% [markdown]
# ----

# %% [markdown]
# # Test 2
# - Test size: 85 %
# - Train size: 15 %

# %%
test_size=0.85
fold_quantity = 100
feature_representation = CountVectorizer()
# Train and gather evaluation metrics
confusion_list = []

evaluate = Eva.Evaluation(df_sliced, feature_representation, test_size, fold_quantity)
classifier_max_ent , metrics_max_ent = evaluate.evaluate_MaxEnt()
classifier_svm , metrics_svm = evaluate.evaluate_SVM()
classifier_naive, metrics_naive = evaluate.evaluate_Naive_Bayes()

metrics = {
    'maxEnt': metrics_max_ent,
    'SVM': metrics_svm,
    'Naive': metrics_naive
}

# %% [markdown]
# # Evaluation
# ## Confusion matrix

# %%
Graphs.plot_horizontal_graphs(metrics, 'norm')

# %% [markdown]
# # Classification report

# %%
Graphs.plot_horizontal_graphs(metrics, 'report')

# %% [markdown]
# # Prediction average

# %%
Graphs.plot_predictionScoreAverage(metrics_max_ent, classifier_max_ent)
Graphs.plot_predictionScoreAverage(metrics_naive, classifier_naive)
Graphs.plot_predictionScoreAverage(metrics_svm, classifier_svm)

# %%
maxEnt_accuracy_test1.append(metrics_max_ent.get_accuracy_score())
svm_accuracy_test1.append(metrics_svm.get_accuracy_score())
naive_accuracy_test1.append(metrics_naive.get_accuracy_score())

maxEnt_precision_test1.append(metrics_max_ent.get_precision_score())
svm_precision_test1.append(metrics_svm.get_precision_score())
naive_precision_test1.append(metrics_naive.get_precision_score())

maxEnt_recall_test1.append(metrics_max_ent.get_recall_score())
svm_recall_test1.append(metrics_svm.get_recall_score())
naive_recall_test1.append(metrics_naive.get_recall_score())

maxEnt_f1_test1.append(metrics_max_ent.get_f1_score())
svm_f1_test1.append(metrics_svm.get_f1_score())
naive_f1_test1.append(metrics_naive.get_f1_score())

# %% [markdown]
# ----

# %% [markdown]
# # Test 3: Test/Train 80/20 (%)

# %%
test_size=0.80
fold_quantity = 100
feature_representation = CountVectorizer()
# Train and gather evaluation metrics
confusion_list = []

evaluate = Eva.Evaluation(df_sliced, feature_representation, test_size, fold_quantity)
classifier_max_ent , metrics_max_ent = evaluate.evaluate_MaxEnt()
classifier_svm , metrics_svm = evaluate.evaluate_SVM()
classifier_naive, metrics_naive = evaluate.evaluate_Naive_Bayes()

metrics = {
    'maxEnt': metrics_max_ent,
    'SVM': metrics_svm,
    'Naive': metrics_naive
}

# %% [markdown]
# # Evaluation
# ## Confusion matrix

# %%
Graphs.plot_horizontal_graphs(metrics, 'norm')

# %% [markdown]
# ## Classification report

# %%
Graphs.plot_horizontal_graphs(metrics, 'report')

# %% [markdown]
# ## prediction average

# %%
Graphs.plot_predictionScoreAverage(metrics_max_ent, classifier_max_ent)
Graphs.plot_predictionScoreAverage(metrics_naive, classifier_naive)
Graphs.plot_predictionScoreAverage(metrics_svm, classifier_svm)

# %%
maxEnt_accuracy_test1.append(metrics_max_ent.get_accuracy_score())
svm_accuracy_test1.append(metrics_svm.get_accuracy_score())
naive_accuracy_test1.append(metrics_naive.get_accuracy_score())

maxEnt_precision_test1.append(metrics_max_ent.get_precision_score())
svm_precision_test1.append(metrics_svm.get_precision_score())
naive_precision_test1.append(metrics_naive.get_precision_score())

maxEnt_recall_test1.append(metrics_max_ent.get_recall_score())
svm_recall_test1.append(metrics_svm.get_recall_score())
naive_recall_test1.append(metrics_naive.get_recall_score())

maxEnt_f1_test1.append(metrics_max_ent.get_f1_score())
svm_f1_test1.append(metrics_svm.get_f1_score())
naive_f1_test1.append(metrics_naive.get_f1_score())

# %% [markdown]
# ----

# %% [markdown]
# # Test 4: Test/Train 75/25 (%)

# %%
test_size=0.75
fold_quantity = 100
feature_representation = CountVectorizer()
# Train and gather evaluation metrics
confusion_list = []

evaluate = Eva.Evaluation(df_sliced, feature_representation, test_size, fold_quantity)
classifier_max_ent , metrics_max_ent = evaluate.evaluate_MaxEnt()
classifier_svm , metrics_svm = evaluate.evaluate_SVM()
classifier_naive, metrics_naive = evaluate.evaluate_Naive_Bayes()

metrics = {
    'maxEnt': metrics_max_ent,
    'SVM': metrics_svm,
    'Naive': metrics_naive
}

# %% [markdown]
# # Evaluation
# ## Confusion matrix

# %%
Graphs.plot_horizontal_graphs(metrics, 'norm')

# %% [markdown]
# ## Classification report

# %%
Graphs.plot_horizontal_graphs(metrics, 'report')

# %% [markdown]
# ## prediction average

# %%
Graphs.plot_predictionScoreAverage(metrics_max_ent, classifier_max_ent)
Graphs.plot_predictionScoreAverage(metrics_naive, classifier_naive)
Graphs.plot_predictionScoreAverage(metrics_svm, classifier_svm)

# %%
maxEnt_accuracy_test1.append(metrics_max_ent.get_accuracy_score())
svm_accuracy_test1.append(metrics_svm.get_accuracy_score())
naive_accuracy_test1.append(metrics_naive.get_accuracy_score())

maxEnt_precision_test1.append(metrics_max_ent.get_precision_score())
svm_precision_test1.append(metrics_svm.get_precision_score())
naive_precision_test1.append(metrics_naive.get_precision_score())

maxEnt_recall_test1.append(metrics_max_ent.get_recall_score())
svm_recall_test1.append(metrics_svm.get_recall_score())
naive_recall_test1.append(metrics_naive.get_recall_score())

maxEnt_f1_test1.append(metrics_max_ent.get_f1_score())
svm_f1_test1.append(metrics_svm.get_f1_score())
naive_f1_test1.append(metrics_naive.get_f1_score())

# %% [markdown]
# # Overall performance for test_size
#     - The static settings: Feature-representation = Bag-of-words ,
#         number of iterations = 10, parsing option = s0
#     - Train size is from 10 % to 25 %, increment 5% with every test
#
# # Graphs
#     - We plot 3 types of graphs, where x-axis is the variable that is tested.
#     - Accuracy: ratio between # of True positives and total files in system
#     - Macro precision: the average of all concerns locally calculated precision
#     - Macro Recall: Same scenario as precision but calculated for recall.

# %%
train_size = ['10%','15%','20%','25%']
y_axis_accuracy = {
    'naive': naive_accuracy_test1,
    'maxEnt': maxEnt_accuracy_test1,
    'svm': svm_accuracy_test1
}

#########ACCURACY#############################

Graphs.plot_line_graph("Accuracy over train size (%)", train_size, y_axis_accuracy, "Train size (%)", "Accuracy", type ="accuracy")
##############################################

##############PRECISION#######################
Graphs.plot_line_graph("Macro avg. precision over train size (%)", train_size, {'naive': naive_precision_test1,
                                                             'maxEnt': maxEnt_precision_test1,
                                                             'svm': svm_precision_test1
                                                            }, "Train size (%)", "Macro.avg. precision", type = "macro")

Graphs.plot_line_graph("Weighted avg. precision over train size (%)", train_size, {'naive': naive_precision_test1,
                                                             'maxEnt': maxEnt_precision_test1,
                                                             'svm': svm_precision_test1
                                                            }, "Train size (%)", "Weighted.avg. precision", type = "weighted")

##############RECALL#######################
Graphs.plot_line_graph("Macro avg. recall over train size (%)", train_size, {'naive': naive_recall_test1,
                                                             'maxEnt': maxEnt_recall_test1,
                                                             'svm': svm_recall_test1
                                                            }, "Train size (%)", "Macro.avg. recall", type = "macro")

Graphs.plot_line_graph("Weighted avg. recall over train size (%)", train_size, {'naive': naive_recall_test1,
                                                             'maxEnt': maxEnt_recall_test1,
                                                             'svm': svm_recall_test1
                                                            }, "Train size (%)", "Weighted.avg. recall", type = "weighted")

##############f1#######################
Graphs.plot_line_graph("Macro avg. F1-score over train size (%)", train_size, {'naive': naive_f1_test1,
                                                             'maxEnt': maxEnt_f1_test1,
                                                             'svm': svm_f1_test1
                                                            }, "Train size (%)", "Macro.avg. F1-score", type = "macro")

Graphs.plot_line_graph("Weighted avg. F1-score over train size (%)", train_size, {'naive': naive_f1_test1,
                                                             'maxEnt': maxEnt_f1_test1,
                                                             'svm': svm_f1_test1
                                                            }, "Train size (%)", "Weighted.avg. F1-score", type = "weighted")

# %%
size_type='ratio'

maxEnt_accuracy_test1
svm_accuracy_test1
naive_accuracy_test1

maxEnt_precision_test1
svm_precision_test1
naive_precision_test1

maxEnt_recall_test1
svm_recall_test1
naive_recall_test1

maxEnt_f1_test1
svm_f1_test1
naive_f1_test1

df_maxEnt = pd.DataFrame({
    'accuracy': maxEnt_accuracy_test1, 
    'precision' : [x[1] for x in maxEnt_precision_test1],
    'recall': [x[1] for x in maxEnt_recall_test1],
    'f1' : [x[1] for x in maxEnt_f1_test1],
    'size' : train_size
    })

df_maxEnt['classifier']='maxEnt'

df_svm = pd.DataFrame({
    'accuracy': svm_accuracy_test1, 
    'precision' : [x[1] for x in svm_precision_test1],
    'recall': [x[1] for x in svm_recall_test1],
    'f1' : [x[1] for x in svm_f1_test1],
    'size' : train_size
    })
df_svm['classifier']='svm'

df_naive = pd.DataFrame({
    'accuracy': naive_accuracy_test1, 
    'precision' : [x[1] for x in naive_precision_test1],
    'recall': [x[1] for x in naive_recall_test1],
    'f1' : [x[1] for x in naive_f1_test1],
    'size' : train_size
    })
df_naive['classifier']='naive'

df = pd.concat([df_maxEnt, df_naive, df_svm])
df['system']=system
df['size type']=size_type

fn = 'size_' + size_type + '_' + system + '.csv'
fp = Path.cwd().parent/'Data'/system/fn

df.to_csv(fp, index=False)
